# %%
#Guarantee Directory
# %cd C:\\Users\\Oluwa\\GITHUB\\Bootcamp\\ASSIGNMENTS\\Project_Uno
# Out:
# C:\Users\Oluwa\GITHUB\Bootcamp\ASSIGNMENTS\Project_Uno

# %%
# initial imports
import pandas as pd
import hvplot.pandas
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

import os
import requests

import yfinance as yf
import pytz
import sys
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#USER INPUT

#INVESTMENT GOALS
print("Would you prefer to analyze based on current or historical data?")
print("If you input 'current' we'll run a short-term analysis on the stocks on the market")
print("If you input 'history' we'll run a long-term analysis on the stocks on the market")

print("")

inv_goal= input("Enter your preferred investment term")

print("")
print("")
# Out:
# Would you prefer to analyze based on current or historical data?
# If you input 'current' we'll run a short-term analysis on the stocks on the market
# If you input 'history' we'll run a long-term analysis on the stocks on the market
# Enter your preferred investment term history

# %%
#### Define functions to run Jupyter Notebook cells
def RunShort():
    # %run -i Short_term_analysis.ipynb
    

def RunLong():
   # %run -i long_term.ipynb

# Check the value of inv_goal and run the appropriate notebook
while True:
    if inv_goal == "current":
        RunShort()
        break
    elif inv_goal == "history":
        RunLong()
        break
    else:
        print("Sorry that's not a valid investment goal, input 'current' or 'history'")
        inv_goal= input("Enter your preferred investment term")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Your choice of 'Risk Term' will define the timeframe with which we will analyze stock returns
# Select a risk term that matches your current investment goals for collecting returns from stock investments
#
# Choose a Risk Term From These Options:
# 1. 1Yrs (1 Year)
# 2. 5Yrs (5 Years)
# 3. 10Yrs (10 Years)
# 4. 15Yrs (15 Years)
# 5. 7Dys (7 Days)
# 6. 21Dys (21 Days)
# 7. 40Dys (40 Days)
# Enter your risk term 10Yrs
# Your choice of 'Risk Threshold' will define how risky and volatile the stocks in the final portfolio will be
# Select a risk threshold that matches your comfort levels when it comes to risk
#
# Choose a Risk Threshold:
# 1. high
# 2. mid
# 3. low
# Enter your risk threshold mid
# [*********************100%%**********************]  1 of 1 completed
# Top 10 tickers with the best 5 year SMA values:
#             SMA_1260
# Ticker
# S&P 500  3666.196245
# CMG      1251.970469
# ADBE      402.642230
# ...

# %%
risk_tickers
# Out:
# ['FL', 'CRM', 'NFLX', 'FDX', 'SPOT', 'DAL', 'LUV', 'ADBE', 'AMZN', 'CMG']

# %%
risk_analyzer
# Out:
#         Value At Risk      Beta  Volatility
# Ticker
# FL          -3.816949  0.584179    3.391106
# CRM         -3.403702 -0.082821    2.839072
# NFLX        -3.900171  0.049730    3.304436
# FDX         -2.751059 -0.016890    1.989909
# SPOT        -4.680662 -0.025671    3.455500
# DAL         -3.535914  0.503098    2.798071
# LUV         -3.282611 -0.583363    2.658401
# ADBE        -3.141588  0.020531    2.380136
# AMZN        -3.109731 -0.585239    2.683304
# CMG         -3.006083  0.027370    9.485610

# %%
risk_analyzer.hvplot(
    xlabel="Ticker", 
    ylabel="Value at Risk / Beta / Volatility",
    title='Value at Risk, Beta and Volatility of chosen portfolio',
    width = 1200
).opts(yformatter='%.0f')
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Ticker]   (value)

# %%
# Check the value of inv_goal and run the appropriate notebook
if inv_goal == "current":
    figure1=(MACD_world_stock_df.hvplot(
    xlabel="Date", 
    ylabel="MACD Line / Single Line",
    title='MACD Line / Single Line',
    width = 2500,
    groupby = 'Ticker'
).opts(yformatter='%.0f'))
    figure2=RSI_world_stock_df.hvplot(
    xlabel="Date", 
    ylabel="7, 21 & 40 Day RSI",
    title='7, 21 & 40 Day RSI',
    width = 2500,
    groupby = 'Ticker'
).opts(yformatter='%.0f')
    figure3=ma_world_stock_df.hvplot(
    xlabel="Date", 
    ylabel="7, 21 & 40 Day MA",
    title='7, 21 & 40 Day Moving Average',
    width = 2500,
    groupby = 'Ticker'
).opts(yformatter='%.0f')
    figure4=daily_return.hvplot(
    xlabel="Date", 
    ylabel="Daily Return",
    title='Daily Returns',
    width = 2500,
    groupby = 'Ticker',
).opts(yformatter='%.0f')
    display(figure1, figure2, figure3, figure4)
    

elif inv_goal == "history":
    figure1=Cum_Ret_finale.hvplot.bar(title="Cumulative Returns for chosen Market Portfolio in comparison to S&P 500")
    figure2=Annualized_finale.hvplot.bar(title="Annualized Returns for chosen Market Portfolio in comparison to S&P 500")
    figure3=Vol_finale.hvplot.bar(title="Stock Volume for chosen Market Portfolio in comparison to S&P 500", ylim=(1e+07,6e+8), width=1000)
    figure4=Sharpe_finale.hvplot.bar(title="Sharpe Ratios for chosen Market Portfolio in comparison to S&P 500", width=1000)
    figure5=SMA_finale.hvplot.bar(title="SMA for chosen Market Portfolio in comparison to S&P 500", width=1000)
    display(figure1, figure2, figure3, figure4, figure5)
else:
    print("Sorry that's not a valid investment goal, input 'current' or 'history'")
# Out:
# :Bars   [index,Variable]   (value)
# :Bars   [index,Variable]   (value)
# :Bars   [index,Variable]   (value)
# :Bars   [index,Variable]   (value)
# :Bars   [index,Variable]   (value)
